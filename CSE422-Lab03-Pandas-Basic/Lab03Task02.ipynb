# %%
import numpy as np
import pandas as pd

p=pd.read_csv('StockPriceData.csv', delimiter=',')
p[['Close']].plot()
p[['Close']].rolling(100).mean().plot()
q=p[['Close']].rolling(100).mean()
p['m']=q
print(p.head(20))
n1=p.dropna()
p.plot()
print(p[['Open','High']].plot())
print(p[['Close','m']].plot())
print(p[['Open','m']].plot())
p[['Close','n1']].plot(ax=plt.n1())
plt.show()
# Out:
#           Date      Open      High       Low     Close  Adj Close  Volume   m
# 0    12/1/2003  1.723811  1.727205  1.718390  1.718597   1.718597     0.0 NaN
# 1    12/2/2003  1.719010  1.732112  1.717298  1.730313   1.730313     0.0 NaN
# 2    12/3/2003  1.730493  1.731812  1.725209  1.728101   1.728101     0.0 NaN
# 3    12/4/2003  1.727414  1.728997  1.718302  1.720697   1.720697     0.0 NaN
# 4    12/5/2003  1.720608  1.733102  1.719809  1.733102   1.733102     0.0 NaN
# 5    12/8/2003  1.733102  1.736202  1.727504  1.734214   1.734214     0.0 NaN
# 6    12/9/2003  1.733703  1.747793  1.733613  1.745414   1.745414     0.0 NaN
# 7   12/10/2003  1.745292  1.748007  1.735900  1.739796   1.739796     0.0 NaN
# 8   12/11/2003  1.740008  1.747702  1.737891  1.746206   1.746206     0.0 NaN
# 9   12/12/2003  1.746298  1.751099  1.744287  1.747305   1.747305     0.0 NaN
# 10  12/15/2003  1.747305  1.748588  1.738889  1.747305   1.747305     0.0 NaN
# ...
